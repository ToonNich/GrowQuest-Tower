# %%
import tensorflow as tf

build_info = tf.sysconfig.get_build_info()
print("CUDA Version:", build_info.get("cuda_version", "Unknown"))
print("cuDNN Version:", build_info.get("cudnn_version", "Unknown"))
print("Is GPU available?", tf.config.list_physical_devices("GPU"))
# Out:
# CUDA Version: 64_112
# cuDNN Version: 64_8
# Is GPU available? [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.10.0

# %%
import matplotlib.pyplot as plt

# Given pixel values from the image
pixels = [5, 5, 5, 10, 10, 5, 5, 10, 10, 5, 5, 10, 10, 5, 5, 10, 10, 5, 5, 5, 10, 5, 5, 5, 5]

# Plot the histogram
plt.hist(pixels, bins=range(12), edgecolor='black', align='left')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.title('Histogram of the Image')
plt.xticks(range(11))  # X-axis from 0 to 10
plt.show()
